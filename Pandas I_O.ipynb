# %% [markdown]
# # Data input output

# %%
import numpy as np
import pandas as np

# %%
import matplotlib.pyplot as plt

# %%
# Plot simple x/y graph
x = [0,1,2]
y = [100,200,300]

# %%
plt.plot(x,y)
